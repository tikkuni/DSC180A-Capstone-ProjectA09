# %% [markdown]
# # Sample Size ($n$) and Correlation ($\hat{\rho}$)

# %% [markdown]
# **Summary**: This notebook illustrates the relationship between sample size ($n$), correlation ($\hat{\rho}$), and its standard error by generating data from a multivariate normal distribution with a fixed center, spread, and correlation matrix.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## I. Sample Size and Standard Error of Correlation
# To demonstrate how the **standard error of correlation ($\hat{\rho}$)** is influenced by changes in sample size, we'll compare how the *variability* of $\hat{\rho}$ differs between smaller and larger sample sizes.

# %%
def generate_rho(n, num_samples=400, mean=[0, 0], rho=0.5):
    '''Generates 400 random samples from the same multivariate normal distribution with a sample size of n. 

    Args:
        n (int)           -- sample size of each multivariate normal distribution
        
    Keyword Args:
        num_samples (int) -- number of samples generated
        mean (list)       -- coordinate of population mean
        rho (float)       -- population value of cor(X1, X2)
    
    Returns:
    (list) each sample correlation value
    '''
    cov = [
        [1, rho],
        [rho, 1]
    ]
    
    rho_hats = [0] * num_samples
    for i in range(num_samples):
        X = np.random.multivariate_normal(mean, cov, size=n)
        X_cov = (X.T @ X - mean) / n
        rho_hats[i] = X_cov[0][1]
    
    return rho_hats

# %% [markdown]
# ### Step 1: Generating Samples

# %% [markdown]
# Here, we simulate 400 samples of 100 data points and 400 samples of 10,000 data points. Then, we calculate the $\hat{\rho}$ of each sample.

# %%
# simulates 400 samples of size of n=100
small_n = 100
small_sample_rho = generate_rho(small_n) # 100 pairwise correlations

# simulates 400 samples of size n=10_000
big_n = 10_000
big_sample_rho = generate_rho(big_n) # 10_000 pairwise correlations

# %%
# sanity check
print(f"{len(small_sample_rho)} pairwise correlations, each calculated using 100 random datapoints")
print(f"{len(big_sample_rho)} pairwaise correlations, each calculated using 10_000 random datapoints")
# Out:
# 400 pairwise correlations, each calculated using 100 random datapoints
# 400 pairwaise correlations, each calculated using 10_000 random datapoints

# %% [markdown]
# ### Step 2: Comparing $\hat{\rho}$ between Smaller (n=100) and Larger (n=10,000) Samples

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
axes[0].plot(small_sample_rho)

axes[0].set(xlabel ='sample number', ylabel = '\u03C1_hat', title =r'$\hat{\rho}$ calculated when $n$=100')
axes[0].set_ylim(0,1)
axes[0].axhline(y=0.5, color='r', linestyle='-', label='\u03C1')

axes[1].plot(big_sample_rho)
axes[1].set(xlabel ='sample number', ylabel = '\u03C1_hat', title =r'$\hat{\rho}$ calculated when $n$=10_000')
axes[1].set_ylim(0,1)
axes[1].axhline(y=0.5, color='r', linestyle='-', label='\u03C1')

# %%
print(f"SE(Correlation) of smaller sample (n={small_n}):  {np.std(small_sample_rho) / np.sqrt(400)}")
print(f"SE(Correlation) of bigger sample (n={big_n}): {np.std(big_sample_rho) / np.sqrt(400)}")
# Out:
# SE(Correlation) of smaller sample (n=100):  0.005399633490518443
# SE(Correlation) of bigger sample (n=10000): 0.0005595640984078483

# %% [markdown]
# The standard error of the sample correlation calculated between $x_1$ and $x_2$ is about 100 times smaller for the samples with 10,000 data points when compared to the samples with 100 data points.
#
# In other words, when we scaled $n$ *up* by $100$, the standard error of $\hat{\rho}$ scaled *down* by $1/\sqrt{100}$.
#
# To explore this relationship between $\hat{\rho}$ and $n$, we can simulate many samples to see how $\hat{\rho}$ changes with $n$.

# %% [markdown]
# ## II. Sample Size and Correlation

# %% [markdown]
# ### Step 1: Generating Samples

# %% [markdown]
# Here, we simulate many, many random samples of different sizes from the same multivariate normal distribution.
#
# The first sample is composed of 100 randomly selected points ($n=100$), and for each sample, we increase $n$ by 50, generating up to 5,000 randomly selected points ($n=5000$) per sample.
#
# For each $n$, we simulate 400 samples, find the pairwise correlation ($\hat{\rho}$) between $x_1$ and $x_2$,  then calculate its standard deviaiton ($\sigma(\hat{\rho})$).

# %%
num_simulations = 98
sd_sample_rhos = [0] * num_simulations
mean_sample_rhos = [0] * num_simulations

expected_rho = 0.5
i = 0
for n in range(100, 5_000, 50):
    sample_rhos = generate_rho(n) 
    sd_sample_rhos[i] = np.std(sample_rhos)
    mean_sample_rhos[i] = np.mean(sample_rhos)
    i += 1

# %% [markdown]
# ### Step 2: Comparing $\sigma(\hat{\rho})$ between Smaller (n=100) and Larger (n=10,000) Samples

# %%
plt.plot(range(100, 5_000, 50), mean_sample_rhos, label='standard deviation of \u03C1_hats')
plt.title(r'Change in $\bar{x}(\hat{\rho})$ as n increases')
plt.axhline(y=0.5, color='r', linestyle='-', label='\u03C1')

plt.show()

# %%
plt.plot(range(100, 5_000, 50), sd_sample_rhos, label=r'$\sigma(\hat{\rho})$')
ax = plt.gca()
n_values = np.linspace(100, 5000, 100)
y_values = 1 / np.sqrt(n_values)
# plots 1/sqrt(n) on the second y-axis
ax.plot(n_values, y_values, color='red', linestyle='-', label=r'$\frac{1}{\sqrt{n}}$')

plt.xlabel('n')
plt.ylabel(r'standard deviation of $\hat{\rho}$s')
ax.set_ylabel(r'1/$\sqrt{n}$')
plt.title(r'Variability in $\hat{\rho}$ as $n$ increases')
plt.legend(loc='upper left')

# %% [markdown]
# As we can see, the correlation ($\hat{\rho}$) between $x_1$ and $x_2$ for each sample varies less from its ***expected value*** $\rho$ as $n$ increases. To be more precise, the standard deviation of $\hat{\rho}$ scales by $\sqrt{n}$ as the sample size increases.

# %% [markdown]
# ## Summary

# %% [markdown]
# When calculating correlation values to understand the functional connectivity of the brain, larger sample sizes will generate correlation values that on average, have less variablity from the true correlation values.
